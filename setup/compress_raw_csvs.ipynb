# %%
from pathlib import Path
import gzip
import shutil

ROOT_DIR = Path("../data/raw")
MAX_SIZE_BYTES = 50 * 1024 * 1024       # 50 MB

for csv_path in ROOT_DIR.rglob("*.csv"):
    # Skip files that are already compressed
    if csv_path.suffix == ".gz":
        continue

    gz_path = csv_path.with_suffix(csv_path.suffix + ".gz")

    # Skip recompressing if .gz already exists
    if gz_path.exists():
        print(f"Skip (already compressed): {gz_path}")
        continue

    orig_size = csv_path.stat().st_size
    orig_mb = orig_size / (1024**2)

    # if orig_size <= MAX_SIZE_BYTES:
    #     print(f"Skip (small enough): {csv_path} ({orig_mb:.2f} MB)")
    #     continue

    print(f"Compressing {csv_path} ({orig_mb:.2f} MB) -> {gz_path}")

    with csv_path.open("rb") as f_in, gzip.open(gz_path, "wb", compresslevel=9) as f_out:
        shutil.copyfileobj(f_in, f_out)

    comp_size = gz_path.stat().st_size
    comp_mb = comp_size / (1024**2)

    print(f"  Done. Compressed size: {comp_mb:.2f} MB "
          f"(saved {(orig_mb - comp_mb):.2f} MB)")
# Out:
# Skip (already compressed): ../data/raw/HD2024.csv.gz
# Skip (already compressed): ../data/raw/All_Data_Combined_2004_2005_2006_2007_2008_2009_2010_2011_2012_2013_2014_2015_2016_2017_2018_2019_2020_2021_2022_2023.csv.gz
# Skip (already compressed): ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2011_12_PP.csv.gz
# Skip (already compressed): ../data/raw/College_Scorecard_Raw_Data_05192025/FieldOfStudyData1819_1920_PP.csv.gz
# Skip (already compressed): ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED1999_00_PP.csv.gz
# Skip (already compressed): ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2006_07_PP.csv.gz
# Skip (already compressed): ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2014_15_PP.csv.gz
# Skip (already compressed): ../data/raw/College_Scorecard_Raw_Data_05192025/Most-Recent-Cohorts-Institution.csv.gz
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2003_04_PP.csv (73.84 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2003_04_PP.csv.gz
#   Done. Compressed size: 9.13 MB (saved 64.71 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED1996_97_PP.csv (65.86 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED1996_97_PP.csv.gz
#   Done. Compressed size: 1.25 MB (saved 64.60 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/FieldOfStudyData1516_1617_PP.csv (131.57 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/FieldOfStudyData1516_1617_PP.csv.gz
#   Done. Compressed size: 7.36 MB (saved 124.21 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/Most-Recent-Cohorts-Field-of-Study.csv (142.53 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/Most-Recent-Cohorts-Field-of-Study.csv.gz
#   Done. Compressed size: 13.42 MB (saved 129.10 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2012_13_PP.csv (96.88 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2012_13_PP.csv.gz
#   Done. Compressed size: 15.64 MB (saved 81.24 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2020_21_PP.csv (71.76 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2020_21_PP.csv.gz
#   Done. Compressed size: 7.44 MB (saved 64.32 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2005_06_PP.csv (79.32 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2005_06_PP.csv.gz
#   Done. Compressed size: 11.01 MB (saved 68.31 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2009_10_PP.csv (86.70 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2009_10_PP.csv.gz
#   Done. Compressed size: 13.65 MB (saved 73.05 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2023_24_PP.csv (64.68 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2023_24_PP.csv.gz
#   Done. Compressed size: 4.86 MB (saved 59.82 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/FieldOfStudyData1617_1718_PP.csv (160.85 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/FieldOfStudyData1617_1718_PP.csv.gz
#   Done. Compressed size: 10.09 MB (saved 150.77 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2018_19_PP.csv (87.72 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2018_19_PP.csv.gz
#   Done. Compressed size: 15.67 MB (saved 72.05 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2017_18_PP.csv (88.30 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2017_18_PP.csv.gz
#   Done. Compressed size: 14.09 MB (saved 74.22 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2000_01_PP.csv (69.13 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2000_01_PP.csv.gz
#   Done. Compressed size: 6.16 MB (saved 62.96 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/FieldOfStudyData1718_1819_PP.csv (140.21 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/FieldOfStudyData1718_1819_PP.csv.gz
#   Done. Compressed size: 10.20 MB (saved 130.01 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2001_02_PP.csv (71.33 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2001_02_PP.csv.gz
#   Done. Compressed size: 7.17 MB (saved 64.16 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2019_20_PP.csv (89.30 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2019_20_PP.csv.gz
#   Done. Compressed size: 15.79 MB (saved 73.50 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2016_17_PP.csv (92.11 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2016_17_PP.csv.gz
#   Done. Compressed size: 15.52 MB (saved 76.59 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED1997_98_PP.csv (67.72 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED1997_98_PP.csv.gz
#   Done. Compressed size: 3.23 MB (saved 64.49 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED1998_99_PP.csv (66.06 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED1998_99_PP.csv.gz
#   Done. Compressed size: 3.83 MB (saved 62.23 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2004_05_PP.csv (75.68 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2004_05_PP.csv.gz
#   Done. Compressed size: 9.60 MB (saved 66.08 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2021_22_PP.csv (63.37 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2021_22_PP.csv.gz
#   Done. Compressed size: 3.33 MB (saved 60.04 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2002_03_PP.csv (71.61 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2002_03_PP.csv.gz
#   Done. Compressed size: 7.77 MB (saved 63.84 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/FieldOfStudyData1920_2021_PP.csv (135.85 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/FieldOfStudyData1920_2021_PP.csv.gz
#   Done. Compressed size: 6.74 MB (saved 129.11 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2015_16_PP.csv (94.63 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2015_16_PP.csv.gz
#   Done. Compressed size: 15.27 MB (saved 79.36 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2013_14_PP.csv (98.45 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2013_14_PP.csv.gz
#   Done. Compressed size: 16.40 MB (saved 82.05 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2007_08_PP.csv (81.26 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2007_08_PP.csv.gz
#   Done. Compressed size: 11.89 MB (saved 69.37 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2008_09_PP.csv (82.08 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2008_09_PP.csv.gz
#   Done. Compressed size: 11.65 MB (saved 70.44 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2022_23_PP.csv (62.88 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2022_23_PP.csv.gz
#   Done. Compressed size: 3.34 MB (saved 59.54 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2010_11_PP.csv (89.73 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2010_11_PP.csv.gz
#   Done. Compressed size: 13.58 MB (saved 76.15 MB)
# Compressing ../data/raw/College_Scorecard_Raw_Data_05192025/FieldOfStudyData1415_1516_PP.csv (128.92 MB) -> ../data/raw/College_Scorecard_Raw_Data_05192025/FieldOfStudyData1415_1516_PP.csv.gz
#   Done. Compressed size: 6.79 MB (saved 122.13 MB)
