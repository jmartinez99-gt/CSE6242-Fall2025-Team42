# %%
import pandas as pd
import pickle

df = pd.read_pickle('../data/merged/full_df.pkl')
df
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 607
#        Year  UNITID                         Institution Name        City  \
# 0      2004  100654                 Alabama A & M University      Normal
# 1      2004  100663      University of Alabama at Birmingham  Birmingham
# 2      2004  100706      University of Alabama in Huntsville  Huntsville
# 3      2004  100724                 Alabama State University  Montgomery
# 4      2004  100751                The University of Alabama  Tuscaloosa
# ...     ...     ...                                      ...         ...
# 38136  2023  495147      Pacific Northwest Christian College   Kennewick
# 38137  2023  497046                 Madera Community College      Madera
# 38138  2023  497833                Marian University-Ancilla    Plymouth
# 38139  2023  498562  Commonwealth University of Pennsylvania  Bloomsburg
# 38140  2023  498571          Pennsylvania Western University  California
#
#       State Code  Region Name        School Type  Predominant Degree  \
# 0             AL    Southeast             Public                   3
# 1             AL    Southeast             Public                   3
# 2             AL    Southeast             Public                   3
# 3             AL    Southeast             Public                   3
# 4             AL    Southeast             Public                   3
# ...          ...          ...                ...                 ...
# 38136         WA     Far West  Private Nonprofit                <NA>
# 38137         CA     Far West             Public                <NA>
# 38138         IN  Great Lakes  Private Nonprofit                <NA>
# 38139         PA     Mid East             Public                <NA>
# 38140         PA     Mid East             Public                <NA>
#
#        Highest Degree   LONGITUDE  ...  Women's Gymnastics Champion  \
# 0                   4  -86.568502  ...                          NaN
# 1                   4  -86.799345  ...                          NaN
# 2                   4  -86.640449  ...                          NaN
# 3                   4  -86.295677  ...                          NaN
# 4                   4  -87.545978  ...                          NaN
# ...               ...         ...  ...                          ...
# 38136               2 -119.161961  ...                          NaN
# 38137               2 -119.997870  ...                          NaN
# 38138               2  -86.445875  ...                          NaN
# 38139               4  -76.447844  ...                          NaN
# 38140               4  -79.886790  ...                          NaN
#
#       Women's Indoor Track & Field Champion  Women's Lacrosse Champion  \
# 0                                       NaN                        NaN
# 1                                       NaN                        NaN
# 2                                       NaN                        NaN
# 3                                       NaN                        NaN
# 4                                       NaN                        NaN
# ...                                     ...                        ...
# 38136                                   NaN                        NaN
# 38137                                   NaN                        NaN
# 38138                                   NaN                        NaN
# 38139                                   NaN                        NaN
# 38140                                   NaN                        NaN
#
#        Women's Outdoor Track & Field Champion  Women's Soccer Champion  \
# 0                                         NaN                      NaN
# 1                                         NaN                      NaN
# 2                                         NaN                      NaN
# 3                                         NaN                      NaN
# 4                                         NaN                      NaN
# ...                                       ...                      ...
# 38136                                     NaN                      NaN
# 38137                                     NaN                      NaN
# 38138                                     NaN                      NaN
# 38139                                     NaN                      NaN
# 38140                                     NaN                      NaN
#
#        Women's Softball Champion  Women's Swimming & Diving Champion  \
# 0                            NaN                                 NaN
# 1                            NaN                                 NaN
# 2                            NaN                                 NaN
# 3                            NaN                                 NaN
# 4                            NaN                                 NaN
# ...                          ...                                 ...
# 38136                        NaN                                 NaN
# 38137                        NaN                                 NaN
# 38138                        NaN                                 NaN
# 38139                        NaN                                 NaN
# 38140                        NaN                                 NaN
#
#        Women's Tennis Champion  Women's Volleyball Champion  Total Champions
# 0                          NaN                          NaN              NaN
# 1                          NaN                          NaN              NaN
# 2                          NaN                          NaN              NaN
# 3                          NaN                          NaN              NaN
# 4                          NaN                          NaN              NaN
# ...                        ...                          ...              ...
# 38136                      NaN                          NaN              NaN
# 38137                      NaN                          NaN              NaN
# 38138                      NaN                          NaN              NaN
# 38139                      NaN                          NaN              NaN
# 38140                      NaN                          NaN              NaN
#
# [38141 rows x 767 columns]

# %%
cluster_dict = pickle.load(open('../data/analysis/clustering.pkl', 'rb'))
for k, v in cluster_dict.items():
    df[k] = v
df
# Out:
#        Year  UNITID                         Institution Name        City  \
# 0      2004  100654                 Alabama A & M University      Normal
# 1      2004  100663      University of Alabama at Birmingham  Birmingham
# 2      2004  100706      University of Alabama in Huntsville  Huntsville
# 3      2004  100724                 Alabama State University  Montgomery
# 4      2004  100751                The University of Alabama  Tuscaloosa
# ...     ...     ...                                      ...         ...
# 38136  2023  495147      Pacific Northwest Christian College   Kennewick
# 38137  2023  497046                 Madera Community College      Madera
# 38138  2023  497833                Marian University-Ancilla    Plymouth
# 38139  2023  498562  Commonwealth University of Pennsylvania  Bloomsburg
# 38140  2023  498571          Pennsylvania Western University  California
#
#       State Code  Region Name        School Type  Predominant Degree  \
# 0             AL    Southeast             Public                   3
# 1             AL    Southeast             Public                   3
# 2             AL    Southeast             Public                   3
# 3             AL    Southeast             Public                   3
# 4             AL    Southeast             Public                   3
# ...          ...          ...                ...                 ...
# 38136         WA     Far West  Private Nonprofit                <NA>
# 38137         CA     Far West             Public                <NA>
# 38138         IN  Great Lakes  Private Nonprofit                <NA>
# 38139         PA     Mid East             Public                <NA>
# 38140         PA     Mid East             Public                <NA>
#
#        Highest Degree   LONGITUDE  ...  Women's Soccer Champion  \
# 0                   4  -86.568502  ...                      NaN
# 1                   4  -86.799345  ...                      NaN
# 2                   4  -86.640449  ...                      NaN
# 3                   4  -86.295677  ...                      NaN
# 4                   4  -87.545978  ...                      NaN
# ...               ...         ...  ...                      ...
# 38136               2 -119.161961  ...                      NaN
# 38137               2 -119.997870  ...                      NaN
# 38138               2  -86.445875  ...                      NaN
# 38139               4  -76.447844  ...                      NaN
# 38140               4  -79.886790  ...                      NaN
#
#       Women's Softball Champion  Women's Swimming & Diving Champion  \
# 0                           NaN                                 NaN
# 1                           NaN                                 NaN
# 2                           NaN                                 NaN
# 3                           NaN                                 NaN
# 4                           NaN                                 NaN
# ...                         ...                                 ...
# 38136                       NaN                                 NaN
# 38137                       NaN                                 NaN
# 38138                       NaN                                 NaN
# 38139                       NaN                                 NaN
# 38140                       NaN                                 NaN
#
#        Women's Tennis Champion  Women's Volleyball Champion  Total Champions  \
# 0                          NaN                          NaN              NaN
# 1                          NaN                          NaN              NaN
# 2                          NaN                          NaN              NaN
# 3                          NaN                          NaN              NaN
# 4                          NaN                          NaN              NaN
# ...                        ...                          ...              ...
# 38136                      NaN                          NaN              NaN
# 38137                      NaN                          NaN              NaN
# 38138                      NaN                          NaN              NaN
# 38139                      NaN                          NaN              NaN
# 38140                      NaN                          NaN              NaN
#
#        cluster (k=3)  cluster (k=5)  cluster (k=7)  cluster (k=9)
# 0                  2              1              4              4
# 1                  2              4              3              1
# 2                  1              3              1              0
# 3                  1              3              1              0
# 4                  1              3              1              8
# ...              ...            ...            ...            ...
# 38136              0              0              0              5
# 38137              0              0              6              5
# 38138              1              3              0              0
# 38139              1              2              5              2
# 38140              1              2              5              8
#
# [38141 rows x 771 columns]

# %%
df.to_csv('../data/tableau/full_data.csv', index=False)

# %%
df.to_csv('../data/tableau/full_data.csv.gz', index=False, compression='gzip')
