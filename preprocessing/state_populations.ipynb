# %%
import pandas as pd

vi = pd.read_excel('../data/raw/POPTOTVIA647NWDB.xlsx', sheet_name='Annual')
vi['Year'] = list(range(2000, 2025))
vi['State'] = 'VI'
vi = vi.rename(columns={'POPTOTVIA647NWDB': 'Population'})
vi = vi.drop(columns=['observation_date'])
cols = [c for c in vi.columns if c != 'Population'] + ['Population']
vi = vi[cols]
vi = vi[(vi['Year'] > 2003) & (vi['Year'] < 2024)]
vi
# Out:
#     Year State  Population
# 4   2004    VI      108466
# 5   2005    VI      108453
# 6   2006    VI      108369
# 7   2007    VI      108337
# 8   2008    VI      108397
# 9   2009    VI      108404
# 10  2010    VI      108357
# 11  2011    VI      108290
# 12  2012    VI      108188
# 13  2013    VI      108041
# 14  2014    VI      107882
# 15  2015    VI      107712
# 16  2016    VI      107516
# 17  2017    VI      107281
# 18  2018    VI      107001
# 19  2019    VI      106669
# 20  2020    VI      106290
# 21  2021    VI      105870
# 22  2022    VI      105413
# 23  2023    VI      104917

# %%
df00 = pd.read_excel('../data/raw/st-est00int-01.xls')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/opt/anaconda3/envs/DVA/lib/python3.13/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~/opt/anaconda3/envs/DVA/lib/python3.13/importlib/__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'xlrd'
#
# During handling of the above exception, another exception occurred:
#
# ...
