# %% [markdown]
# # CollegeScorecard

# %%
import pandas as pd
df = pd.read_csv('../data/raw/College_Scorecard_Raw_Data_05192025/MERGED2023_24_PP.csv', low_memory=False)
df
# Out:
#         UNITID      OPEID   OPEID6  \
# 0       100654   100200.0   1002.0
# 1       100663   105200.0   1052.0
# 2       100690  2503400.0  25034.0
# 3       100706   105500.0   1055.0
# 4       100724   100500.0   1005.0
# ...        ...        ...      ...
# 6424  49382201  4283601.0  42836.0
# 6425  49425001  2609404.0  26094.0
# 6426  49501301  4247201.0  42472.0
# 6427  49501302  4247202.0  42472.0
# 6428  49664501  4285601.0  42856.0
#
#                                                  INSTNM        CITY STABBR  \
# 0                              Alabama A & M University      Normal     AL
# 1                   University of Alabama at Birmingham  Birmingham     AL
# 2                                    Amridge University  Montgomery     AL
# 3                   University of Alabama in Huntsville  Huntsville     AL
# 4                              Alabama State University  Montgomery     AL
# ...                                                 ...         ...    ...
# 6424         College Unbound - Newport/Aquidneck Island     Newport     RI
# 6425      Valley College - Fairlawn - School of Nursing    Fairlawn     OH
# 6426  Western Maricopa Education Center - Southwest ...     Buckeye     AZ
# 6427  Western Maricopa Education Center - Northeast ...     Phoenix     AZ
# 6428  Burlington County Institute of Technology - Ad...     Medford     NJ
#
#              ZIP                                       ACCREDAGENCY  \
# 0          35762  Southern Association of Colleges and Schools C...
# 1     35294-0110  Southern Association of Colleges and Schools C...
# 2     36117-3553  Southern Association of Colleges and Schools C...
# 3          35899  Southern Association of Colleges and Schools C...
# 4     36104-0271  Southern Association of Colleges and Schools C...
# ...          ...                                                ...
# 6424   028400000         New England Commission on Higher Education
# 6425   443333631  Accrediting Commission of Career Schools and C...
# 6426  85326-5705                  Council on Occupational Education
# 6427  85027-0000                  Council on Occupational Education
# 6428   080550000    Middle States Commission on Secondary Education
#
#                                  INSTURL  \
# 0                          www.aamu.edu/
# 1                   https://www.uab.edu/
# 2     https://www.amridgeuniversity.edu/
# 3                           www.uah.edu/
# 4                         www.alasu.edu/
# ...                                  ...
# 6424     https://www.collegeunbound.edu/
# 6425             https://www.valley.edu/
# 6426  https://west-mec.edu/findyourhappy
# 6427  https://west-mec.edu/findyourhappy
# 6428     https://www.bcit.cc/bcitadulted
#
#                                                  NPCURL  ...  \
# 0     www.aamu.edu/admissions-aid/tuition-fees/net-p...  ...
# 1     https://tcc.ruffalonl.com/University of Alabam...  ...
# 2              https://www2.amridgeuniversity.edu:9091/  ...
# 3                                       finaid.uah.edu/  ...
# 4     www.alasu.edu/cost-aid/tuition-costs/net-price...  ...
# ...                                                 ...  ...
# 6424                                                NaN  ...
# 6425                                                NaN  ...
# 6426                                                NaN  ...
# 6427                                                NaN  ...
# 6428                                                NaN  ...
#
#       COUNT_WNE_MALE1_P11  GT_THRESHOLD_P11  MD_EARN_WNE_INC1_P11  \
# 0                     NaN               NaN                   NaN
# 1                     NaN               NaN                   NaN
# 2                     NaN               NaN                   NaN
# 3                     NaN               NaN                   NaN
# 4                     NaN               NaN                   NaN
# ...                   ...               ...                   ...
# 6424                  NaN               NaN                   NaN
# 6425                  NaN               NaN                   NaN
# 6426                  NaN               NaN                   NaN
# 6427                  NaN               NaN                   NaN
# 6428                  NaN               NaN                   NaN
#
#       MD_EARN_WNE_INC2_P11  MD_EARN_WNE_INC3_P11  MD_EARN_WNE_INDEP0_P11  \
# 0                      NaN                   NaN                     NaN
# 1                      NaN                   NaN                     NaN
# 2                      NaN                   NaN                     NaN
# 3                      NaN                   NaN                     NaN
# 4                      NaN                   NaN                     NaN
# ...                    ...                   ...                     ...
# 6424                   NaN                   NaN                     NaN
# 6425                   NaN                   NaN                     NaN
# 6426                   NaN                   NaN                     NaN
# 6427                   NaN                   NaN                     NaN
# 6428                   NaN                   NaN                     NaN
#
#       MD_EARN_WNE_INDEP1_P11  MD_EARN_WNE_MALE0_P11  MD_EARN_WNE_MALE1_P11  \
# 0                        NaN                    NaN                    NaN
# 1                        NaN                    NaN                    NaN
# 2                        NaN                    NaN                    NaN
# 3                        NaN                    NaN                    NaN
# 4                        NaN                    NaN                    NaN
# ...                      ...                    ...                    ...
# 6424                     NaN                    NaN                    NaN
# 6425                     NaN                    NaN                    NaN
# 6426                     NaN                    NaN                    NaN
# 6427                     NaN                    NaN                    NaN
# 6428                     NaN                    NaN                    NaN
#
#       SCORECARD_SECTOR
# 0                    4
# 1                    4
# 2                    5
# 3                    4
# 4                    4
# ...                ...
# 6424                14
# 6425                15
# 6426                13
# 6427                13
# 6428                13
#
# [6429 rows x 3306 columns]

# %% [markdown]
# Not much needs to be done, just updating dtypes

# %%
import yaml

# Load YAML
with open("../data/raw/College_Scorecard_Raw_Data_05192025/data.yaml", "r") as f:
    y = yaml.safe_load(f)

# Build source → dtype map
dtype_map = {}
for key, info in y["dictionary"].items():
    src = info.get("source")
    typ = info.get("type")

    if src and typ:
        if typ == "integer":
            dtype = "Int64"
        elif typ == "float":
            dtype = "float"
        else:
            dtype = "string"
        dtype_map[src] = dtype

for override_col in ["OPEID", "OPEID6"]:
    if override_col in df.columns:
        dtype_map[override_col] = "Int64"

# Apply dtypes only if column exists
for col, dtype in dtype_map.items():
    if col in df.columns:
        try:
            df[col] = df[col].astype(dtype)
        except Exception as e:
            print(f"Could not convert {col} to {dtype}: {e}")
# Out:
# Could not convert C150_L4_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert C150_4_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert C200_L4_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert C200_4_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert RET_FT4_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert RET_FTL4_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert RET_PT4_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert RET_PTL4_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert TRANS_4_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert TRANS_L4_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert C100_4_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert C100_L4_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP6_FTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_FTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP8_FTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP8_FTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP8_FTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP6_PTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_PTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP8_PTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP8_PTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP8_PTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP6_FTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_FTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP8_FTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP8_FTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP8_FTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP6_PTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_PTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP8_PTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP8_PTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP8_PTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP_ALL_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP_ALL_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_ALL_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP_ALL_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP_FIRSTTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP_FIRSTTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_FIRSTTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP_FIRSTTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP_NOTFIRSTTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP_NOTFIRSTTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_NOTFIRSTTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP_NOTFIRSTTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP_FULLTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP_FULLTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_FULLTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP_FULLTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP_PARTTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP_PARTTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_PARTTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP_PARTTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert FTFTPCTPELL_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert FTFTPCTFLOAN_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UG_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_FED_UG_DFLT to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UG_DLNQ to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UG_FBR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UG_DFR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UG_NOPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UG_MAKEPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UG_PAIDINFULL to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UG_DISCHARGE to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGCOMP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_FED_UGCOMP_DFLT to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGCOMP_DLNQ to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGCOMP_FBR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGCOMP_DFR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGCOMP_NOPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGCOMP_MAKEPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGCOMP_PAIDINFULL to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGCOMP_DISCHARGE to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGNOCOMP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_FED_UGNOCOMP_DFLT to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGNOCOMP_DLNQ to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGNOCOMP_FBR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGNOCOMP_DFR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGNOCOMP_NOPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGNOCOMP_MAKEPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGNOCOMP_PAIDINFULL to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGNOCOMP_DISCHARGE to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGUNK_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_FED_UGUNK_DFLT to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGUNK_DLNQ to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGUNK_FBR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGUNK_DFR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGUNK_NOPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGUNK_MAKEPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGUNK_PAIDINFULL to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGUNK_DISCHARGE to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GR_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_FED_GR_DFLT to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GR_DLNQ to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GR_FBR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GR_DFR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GR_NOPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GR_MAKEPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GR_PAIDINFULL to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GR_DISCHARGE to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRCOMP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_FED_GRCOMP_DFLT to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRCOMP_DLNQ to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRCOMP_FBR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRCOMP_DFR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRCOMP_NOPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRCOMP_MAKEPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRCOMP_PAIDINFULL to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRCOMP_DISCHARGE to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRNOCOMP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_FED_GRNOCOMP_DFLT to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRNOCOMP_DLNQ to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRNOCOMP_FBR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRNOCOMP_DFR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRNOCOMP_NOPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRNOCOMP_MAKEPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRNOCOMP_PAIDINFULL to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRNOCOMP_DISCHARGE to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UG_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_PP_UG_DFLT to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UG_DLNQ to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UG_FBR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UG_DFR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UG_NOPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UG_MAKEPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UG_PAIDINFULL to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UG_DISCHARGE to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGCOMP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_PP_UGCOMP_DFLT to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGCOMP_DLNQ to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGCOMP_FBR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGCOMP_DFR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGCOMP_NOPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGCOMP_MAKEPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGCOMP_PAIDINFULL to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGCOMP_DISCHARGE to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGNOCOMP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_PP_UGNOCOMP_DFLT to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGNOCOMP_DLNQ to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGNOCOMP_FBR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGNOCOMP_DFR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGNOCOMP_NOPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGNOCOMP_MAKEPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGNOCOMP_PAIDINFULL to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGNOCOMP_DISCHARGE to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGUNK_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_PP_UGUNK_DFLT to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGUNK_DLNQ to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGUNK_FBR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGUNK_DFR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGUNK_NOPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGUNK_MAKEPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGUNK_PAIDINFULL to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGUNK_DISCHARGE to float: could not convert string to float: 'PS'
# Could not convert C150_L4_PELL_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert C150_4_PELL_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_PELL_FTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP8_PELL_FTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP8_PELL_FTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP8_PELL_FTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_PELL_PTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP8_PELL_PTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP8_PELL_PTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP8_PELL_PTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_PELL_FTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP8_PELL_FTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP8_PELL_FTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP8_PELL_FTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_PELL_PTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP8_PELL_PTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP8_PELL_PTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP8_PELL_PTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP_PELL_ALL_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP_PELL_ALL_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_PELL_ALL_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP_PELL_ALL_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP_PELL_FTT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP_PELL_FTT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_PELL_FTT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP_PELL_FTT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP_PELL_NFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP_PELL_NFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_PELL_NFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP_PELL_NFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP_PELL_FT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP_PELL_FT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_PELL_FT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP_PELL_FT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP_PELL_PT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP_PELL_PT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_PELL_PT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP_PELL_PT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_IND_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_FED_DEP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_FED_PELL_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_FED_NOPELL_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_FED_MALE_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_FED_NOMALE_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_PP_IND_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_PP_DEP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_PP_PELL_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_PP_NOPELL_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_PP_MALE_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_PP_NOMALE_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_FED_UG_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_FED_UGCOMP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_FED_UGNOCOMP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_FED_UGUNK_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_FED_GR_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_FED_GRCOMP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_FED_GRNOCOMP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_PP_UG_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_PP_UGCOMP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_PP_UGNOCOMP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_PP_UGUNK_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_FED_IND_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_FED_DEP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_FED_PELL_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_FED_NOPELL_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_FED_MALE_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_FED_NOMALE_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_PP_IND_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_PP_DEP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_PP_PELL_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_PP_NOPELL_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_PP_MALE_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_PP_NOMALE_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert ADM_RATE_SUPP to float: could not convert string to float: 'PS'
# Could not convert PCTPELL_DCS_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert PCTFLOAN_DCS_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert C150_L4_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert C150_4_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert C200_L4_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert C200_4_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert RET_FT4_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert RET_FTL4_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert RET_PT4_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert RET_PTL4_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert TRANS_4_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert TRANS_L4_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert C100_4_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert C100_L4_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP6_FTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_FTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP8_FTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP8_FTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP8_FTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP6_PTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_PTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP8_PTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP8_PTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP8_PTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP6_FTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_FTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP8_FTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP8_FTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP8_FTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP6_PTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_PTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP8_PTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP8_PTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP8_PTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP_ALL_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP_ALL_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_ALL_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP_ALL_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP_FIRSTTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP_FIRSTTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_FIRSTTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP_FIRSTTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP_NOTFIRSTTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP_NOTFIRSTTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_NOTFIRSTTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP_NOTFIRSTTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP_FULLTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP_FULLTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_FULLTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP_FULLTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP_PARTTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP_PARTTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_PARTTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP_PARTTIME_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert FTFTPCTPELL_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert FTFTPCTFLOAN_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UG_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_FED_UG_DFLT to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UG_DLNQ to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UG_FBR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UG_DFR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UG_NOPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UG_MAKEPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UG_PAIDINFULL to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UG_DISCHARGE to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGCOMP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_FED_UGCOMP_DFLT to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGCOMP_DLNQ to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGCOMP_FBR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGCOMP_DFR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGCOMP_NOPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGCOMP_MAKEPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGCOMP_PAIDINFULL to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGCOMP_DISCHARGE to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGNOCOMP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_FED_UGNOCOMP_DFLT to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGNOCOMP_DLNQ to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGNOCOMP_FBR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGNOCOMP_DFR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGNOCOMP_NOPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGNOCOMP_MAKEPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGNOCOMP_PAIDINFULL to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGNOCOMP_DISCHARGE to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGUNK_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_FED_UGUNK_DFLT to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGUNK_DLNQ to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGUNK_FBR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGUNK_DFR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGUNK_NOPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGUNK_MAKEPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGUNK_PAIDINFULL to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_UGUNK_DISCHARGE to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GR_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_FED_GR_DFLT to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GR_DLNQ to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GR_FBR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GR_DFR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GR_NOPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GR_MAKEPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GR_PAIDINFULL to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GR_DISCHARGE to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRCOMP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_FED_GRCOMP_DFLT to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRCOMP_DLNQ to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRCOMP_FBR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRCOMP_DFR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRCOMP_NOPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRCOMP_MAKEPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRCOMP_PAIDINFULL to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRCOMP_DISCHARGE to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRNOCOMP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_FED_GRNOCOMP_DFLT to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRNOCOMP_DLNQ to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRNOCOMP_FBR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRNOCOMP_DFR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRNOCOMP_NOPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRNOCOMP_MAKEPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRNOCOMP_PAIDINFULL to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_GRNOCOMP_DISCHARGE to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UG_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_PP_UG_DFLT to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UG_DLNQ to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UG_FBR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UG_DFR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UG_NOPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UG_MAKEPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UG_PAIDINFULL to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UG_DISCHARGE to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGCOMP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_PP_UGCOMP_DFLT to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGCOMP_DLNQ to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGCOMP_FBR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGCOMP_DFR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGCOMP_NOPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGCOMP_MAKEPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGCOMP_PAIDINFULL to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGCOMP_DISCHARGE to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGNOCOMP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_PP_UGNOCOMP_DFLT to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGNOCOMP_DLNQ to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGNOCOMP_FBR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGNOCOMP_DFR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGNOCOMP_NOPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGNOCOMP_MAKEPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGNOCOMP_PAIDINFULL to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGNOCOMP_DISCHARGE to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGUNK_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_PP_UGUNK_DFLT to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGUNK_DLNQ to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGUNK_FBR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGUNK_DFR to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGUNK_NOPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGUNK_MAKEPROG to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGUNK_PAIDINFULL to float: could not convert string to float: 'PS'
# Could not convert BBRR1_PP_UGUNK_DISCHARGE to float: could not convert string to float: 'PS'
# Could not convert C150_L4_PELL_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert C150_4_PELL_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_PELL_FTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP8_PELL_FTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP8_PELL_FTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP8_PELL_FTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_PELL_PTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP8_PELL_PTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP8_PELL_PTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP8_PELL_PTFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_PELL_FTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP8_PELL_FTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP8_PELL_FTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP8_PELL_FTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_PELL_PTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP8_PELL_PTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP8_PELL_PTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP8_PELL_PTNFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP_PELL_ALL_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP_PELL_ALL_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_PELL_ALL_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP_PELL_ALL_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP_PELL_FTT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP_PELL_FTT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_PELL_FTT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP_PELL_FTT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP_PELL_NFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP_PELL_NFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_PELL_NFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP_PELL_NFT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP_PELL_FT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP_PELL_FT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_PELL_FT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP_PELL_FT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRYP_PELL_PT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRAP_PELL_PT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMAWDP8_PELL_PT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert OMENRUP_PELL_PT_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert BBRR1_FED_IND_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_FED_DEP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_FED_PELL_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_FED_NOPELL_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_FED_MALE_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_FED_NOMALE_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_PP_IND_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_PP_DEP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_PP_PELL_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_PP_NOPELL_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_PP_MALE_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR1_PP_NOMALE_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_FED_UG_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_FED_UGCOMP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_FED_UGNOCOMP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_FED_UGUNK_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_FED_GR_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_FED_GRCOMP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_FED_GRNOCOMP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_PP_UG_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_PP_UGCOMP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_PP_UGNOCOMP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_PP_UGUNK_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_FED_IND_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_FED_DEP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_FED_PELL_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_FED_NOPELL_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_FED_MALE_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_FED_NOMALE_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_PP_IND_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_PP_DEP_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_PP_PELL_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_PP_NOPELL_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_PP_MALE_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert BBRR4_PP_NOMALE_N to Int64: invalid literal for int() with base 10: 'PS'
# Could not convert ADM_RATE_SUPP to float: could not convert string to float: 'PS'
# Could not convert PCTPELL_DCS_POOLED_SUPP to float: could not convert string to float: 'PS'
# Could not convert PCTFLOAN_DCS_POOLED_SUPP to float: could not convert string to float: 'PS'

# %% [markdown]
# ## Exporting Data

# %%
all_years = []
for yr in range(4, 24):
    origin_file = f'MERGED20{yr:02d}_{yr+1:02d}_PP.csv'
    # destination_file = f'CollegeScorecard_{yr+2000}.csv'
    destination_file = f'CollegeScorecard_{yr+2000}.pkl'

    df = pd.read_csv(f'../data/raw/College_Scorecard_Raw_Data_05192025/{origin_file}', low_memory=False)

    for override_col in ["OPEID", "OPEID6"]:
        if override_col in df.columns:
            dtype_map[override_col] = "Int64"

    for col, dtype in dtype_map.items():
        if col in df.columns:
            try:
                df[col] = df[col].astype(dtype)
            except Exception as e:
                pass

    df = df.assign(Year=yr + 2000)
    cols = ["Year"] + [c for c in df.columns if c != "Year"]
    df = df[cols]

    # df.to_csv(f'../data/processed/{destination_file}', index=False)
    df.to_pickle(f'../data/processed/{destination_file}')
    all_years.append(df)
    print(origin_file, destination_file)

merged_df = pd.concat(all_years, ignore_index=True)
# merged_df.to_csv(f'../data/processed/CollegeScorecard_AllYears.csv', index=False)
merged_df.to_pickle(f'../data/processed/CollegeScorecard_AllYears.pkl')
# Out:
# MERGED2004_05_PP.csv CollegeScorecard_2004.pkl
# MERGED2005_06_PP.csv CollegeScorecard_2005.pkl
# MERGED2006_07_PP.csv CollegeScorecard_2006.pkl
# MERGED2007_08_PP.csv CollegeScorecard_2007.pkl
# MERGED2008_09_PP.csv CollegeScorecard_2008.pkl
# MERGED2009_10_PP.csv CollegeScorecard_2009.pkl
# MERGED2010_11_PP.csv CollegeScorecard_2010.pkl
# MERGED2011_12_PP.csv CollegeScorecard_2011.pkl
# MERGED2012_13_PP.csv CollegeScorecard_2012.pkl
# MERGED2013_14_PP.csv CollegeScorecard_2013.pkl
# MERGED2014_15_PP.csv CollegeScorecard_2014.pkl
# MERGED2015_16_PP.csv CollegeScorecard_2015.pkl
# MERGED2016_17_PP.csv CollegeScorecard_2016.pkl
# MERGED2017_18_PP.csv CollegeScorecard_2017.pkl
# MERGED2018_19_PP.csv CollegeScorecard_2018.pkl
# MERGED2019_20_PP.csv CollegeScorecard_2019.pkl
# MERGED2020_21_PP.csv CollegeScorecard_2020.pkl
# MERGED2021_22_PP.csv CollegeScorecard_2021.pkl
# MERGED2022_23_PP.csv CollegeScorecard_2022.pkl
# MERGED2023_24_PP.csv CollegeScorecard_2023.pkl
# MERGED2004_05_PP.csv CollegeScorecard_2004.pkl
# MERGED2005_06_PP.csv CollegeScorecard_2005.pkl
# MERGED2006_07_PP.csv CollegeScorecard_2006.pkl
# MERGED2007_08_PP.csv CollegeScorecard_2007.pkl
# MERGED2008_09_PP.csv CollegeScorecard_2008.pkl
# MERGED2009_10_PP.csv CollegeScorecard_2009.pkl
# MERGED2010_11_PP.csv CollegeScorecard_2010.pkl
# MERGED2011_12_PP.csv CollegeScorecard_2011.pkl
# MERGED2012_13_PP.csv CollegeScorecard_2012.pkl
# MERGED2013_14_PP.csv CollegeScorecard_2013.pkl
# MERGED2014_15_PP.csv CollegeScorecard_2014.pkl
# MERGED2015_16_PP.csv CollegeScorecard_2015.pkl
# MERGED2016_17_PP.csv CollegeScorecard_2016.pkl
# MERGED2017_18_PP.csv CollegeScorecard_2017.pkl
# MERGED2018_19_PP.csv CollegeScorecard_2018.pkl
# MERGED2019_20_PP.csv CollegeScorecard_2019.pkl
# MERGED2020_21_PP.csv CollegeScorecard_2020.pkl
# MERGED2021_22_PP.csv CollegeScorecard_2021.pkl
# MERGED2022_23_PP.csv CollegeScorecard_2022.pkl
# MERGED2023_24_PP.csv CollegeScorecard_2023.pkl
