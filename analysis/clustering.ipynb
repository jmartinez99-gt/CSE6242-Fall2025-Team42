# %%
import pandas as pd

df = pd.read_pickle('../data/merged/SportParticipation_CollegeScorecard_full.pkl')
df
# Out:
#        Year  UNITID   OPE ID                      Institution Name State Code  \
# 0      2004  222178   353700          Abilene Christian University         TX
# 1      2004  138558   154100  Abraham Baldwin Agricultural College         GA
# 2      2004  126182   134500                   Adams State College         CO
# 3      2004  188429   266600                    Adelphi University         NY
# 4      2004  188438   286000          Adirondack Community College         NY
# ...     ...     ...      ...                                   ...        ...
# 38114  2023  420440  3122900         York County Community College         ME
# 38115  2023  181853   256700                       York University         NE
# 38116  2023  141361   160400                  Young Harris College         GA
# 38117  2023  206695   314500           Youngstown State University         OH
# 38118  2023  126119   134400                          Yuba College         CA
#
# ...

# %%
id_cols = ['Year', 'UNITID', 'Institution Name', 'State Code', 'Sanction Name']
pop_cols = ['Male Undergraduates', 'Female Undergraduates']

column_names = list(df.columns)
expense_cols = [expense for expense in column_names if 'Total Expenses' in expense]
expense_cols
# Out:
# ['Archery Total Expenses',
#  'Badminton Total Expenses',
#  'Baseball Total Expenses',
#  'Basketball Total Expenses',
#  'Beach Volleyball Total Expenses',
#  'Bowling Total Expenses',
#  'All Track Combined Total Expenses',
#  'Diving Total Expenses',
#  'Equestrian Total Expenses',
#  'Fencing Total Expenses',
#  'Field Hockey Total Expenses',
#  'Football Total Expenses',
#  'Golf Total Expenses',
#  'Gymnastics Total Expenses',
#  'Ice Hockey Total Expenses',
#  'Lacrosse Total Expenses',
#  'Rifle Total Expenses',
#  'Rodeo Total Expenses',
#  'Rowing Total Expenses',
#  'Sailing Total Expenses',
#  'Skiing Total Expenses',
#  'Soccer Total Expenses',
#  'Softball Total Expenses',
#  'Squash Total Expenses',
#  'Swimming and Diving Total Expenses',
#  'Swimming Total Expenses',
#  'Synchronized Swimming Total Expenses',
#  'Table Tennis Total Expenses',
#  'Team Handball Total Expenses',
#  'Tennis Total Expenses',
#  'Track and Field Indoor Total Expenses',
# ...

# %%
coach_cols = [coach for coach in column_names if 'Salary per' in coach]
coach_cols = [coach for coach in coach_cols if 'Coach' in coach]
coach_cols
# Out:
# ["Men's Team Average Annual Institutional Salary per Head Coach",
#  " Women's Team Average Annual Institutional Salary per Head Coach",
#  ' Coed Team Average Annual Institutional Salary per Head Coach',
#  "Men's Team Average Annual Institutional Salary per Assistant Coach",
#  " Women's Team Average Annual Institutional Salary per Assistant Coach",
#  ' Coed Team Average Annual Institutional Salary per Assistant Coach']

# %%
academic_cols = ['SCH_DEG', 'NPCURL', 'LONGITUDE', 'NPT4_PUB', 'NPT4_PRIV', ]
df[['Institution Name', 'Year'] + academic_cols]
# Out:
#                            Institution Name  Year  SCH_DEG  \
# 0              Abilene Christian University  2004        3
# 1      Abraham Baldwin Agricultural College  2004        2
# 2                       Adams State College  2004        3
# 3                        Adelphi University  2004        3
# 4              Adirondack Community College  2004        2
# ...                                     ...   ...      ...
# 38114         York County Community College  2023     <NA>
# 38115                       York University  2023     <NA>
# 38116                  Young Harris College  2023     <NA>
# 38117           Youngstown State University  2023     <NA>
# 38118                          Yuba College  2023     <NA>
#
#                                                   NPCURL   LONGITUDE  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# ...

# %%
df[~df['COSTT4_P'].isna()]
# Out:
#        Year  UNITID  OPE ID                    Institution Name State Code  \
# 12021  2010  155618  526700  Northwest Kansas Technical College         KS
# 13906  2011  155618  526700  Northwest Kansas Technical College         KS
# 15811  2012  155618  526700  Northwest Kansas Technical College         KS
# 17715  2013  155618  526700  Northwest Kansas Technical College         KS
# 19633  2014  155618  526700  Northwest Kansas Technical College         KS
# 21566  2015  155618  526700  Northwest Kansas Technical College         KS
# 23509  2016  155618  526700  Northwest Kansas Technical College         KS
# 25460  2017  155618  526700  Northwest Kansas Technical College         KS
# 27429  2018  155618  526700  Northwest Kansas Technical College         KS
# 29409  2019  155618  526700  Northwest Kansas Technical College         KS
# 31297  2020  155618  526700  Northwest Kansas Technical College         KS
# ...

# %%
c = df[(df['Institution Name'] == 'Harvard University') | (df['Institution Name'] == 'Rogers State University')]

constants = ['Year', 'UNITID', 'City', 'LONGITUDE', 'LATITUDE', 'HBCU', 'Region Name']
constant_dict = {
    'SCH_DEG': 'Predominant Degree',
    'HIGHDEG': 'Highest Degree',
    'HSI': 'Hispanic Serving College'
}

variable = []
variable_dict = {
    'ACTENMID': 'Median ACT English',
    'ACTMTMID': 'Median ACT Math',
    'ACTWRMID': 'Median ACT Writing',
    'ACTCMMID': 'Median ACT Score',
    'SAT_AVG': 'Average SAT Score',
    'NPT4_PUB': 'Net Price of Public', #ideally combine these to be net price
    'NPT4_PRIV': 'Net Price of Private',
    'TUITIONFEE_IN': 'In-State Tuition',
    'TUITIONFEE_OUT': 'Out-of-State Tuition',
    'COSTT4_A': 'Estimated Cost of Attendence',
    'ADM_RATE': 'Admissions Rate',
    'AVGFACSAL': 'Average Faculty Salary',
    'MD_EARN_WNE_P10': 'Median Earnings after 10yrs',
    'COUNT_NWNE_P10': 'Number of Students Unemployed after 10yrs', # should adjust to proportion
    'UG': 'Number of Undergrad Students',
    'GRADS': 'Number of Grad Students',
    'STUFACR': 'Student to Faculty Ratio',
    'ROOMBOARD_OFF': 'Off-Campus Room and Board'
}
test = ['SATWRMID']
c[['Institution Name', 'Year'] + test]
# Out:
#               Institution Name  Year  SATWRMID
# 589         Harvard University  2004       NaN
# 2378        Harvard University  2005       NaN
# 4166        Harvard University  2006     735.0
# 5980        Harvard University  2007     745.0
# 6582   Rogers State University  2007       NaN
# 7835        Harvard University  2008     740.0
# 8442   Rogers State University  2008       NaN
# 9704        Harvard University  2009     735.0
# 10311  Rogers State University  2009       NaN
# 11583       Harvard University  2010     755.0
# 12194  Rogers State University  2010       NaN
# 13470       Harvard University  2011     740.0
# 14078  Rogers State University  2011       NaN
# 15370       Harvard University  2012     755.0
# 15983  Rogers State University  2012       NaN
# 17276       Harvard University  2013     755.0
# 17886  Rogers State University  2013       NaN
# 19194       Harvard University  2014     760.0
# 19804  Rogers State University  2014       NaN
# ...

# %%
test = 'CONTROL_PEPS'
f = df[['Year', 'Institution Name', test]]
# f[f[test] == 3]
# f[test].hist()
# f[test] = pd.to_numeric(df[test], errors='coerce')
f[test].value_counts()
# f.sort_values(test, ascending=False)
# Out:
# CONTROL_PEPS
# Public               1168
# Private Nonprofit     854
# Proprietary            15
# Name: count, dtype: int64

# %%
a = pd.read_pickle('../data/processed/CollegeScorecard_AllYears.pkl')
a
# Out:
#         Year    UNITID     OPEID  OPEID6  \
# 0       2004    100636  01230800   12308
# 1       2004    100654  00100200    1002
# 2       2004    100663  00105200    1052
# 3       2004    100690  02503400   25034
# 4       2004    100706  00105500    1055
# ...      ...       ...       ...     ...
# 142202  2023  49382201   4283601   42836
# 142203  2023  49425001   2609404   26094
# 142204  2023  49501301   4247201   42472
# 142205  2023  49501302   4247202   42472
# 142206  2023  49664501   4285601   42856
#
#                                                    INSTNM        CITY STABBR  \
# 0                      Community College of the Air Force  Montgomery     AL
# 1                                Alabama A & M University      Normal     AL
# 2                     University of Alabama at Birmingham  Birmingham     AL
# 3                                      Amridge University  Montgomery     AL
# 4                     University of Alabama in Huntsville  Huntsville     AL
# ...

# %%
ipeds_region = {
    1: "New England",
    2: "Mid East",
    3: "Great Lakes",
    4: "Plains",
    5: "Southeast",
    6: "Southwest",
    7: "Rocky Mountains",
    8: "Far West",
    9: "Outlying Areas"
}
df['RegionName'] = df['REGION'].map(ipeds_region)

# %%
pcip_to_pctdeg = {
    'PCIP01': 'Pct Deg Agriculture',
    'PCIP03': 'Pct Deg Resources',
    'PCIP04': 'Pct Deg Architecture',
    'PCIP05': 'Pct Deg Ethnic Cultural Gender',
    'PCIP09': 'Pct Deg Communication',
    'PCIP10': 'Pct Deg Communications Technology',
    'PCIP11': 'Pct Deg Computer',
    'PCIP12': 'Pct Deg Personal Culinary',
    'PCIP13': 'Pct Deg Education',
    'PCIP14': 'Pct Deg Engineering',
    'PCIP15': 'Pct Deg Engineering Technology',
    'PCIP16': 'Pct Deg Language',
    'PCIP19': 'Pct Deg Family Consumer Science',
    'PCIP22': 'Pct Deg Legal',
    'PCIP23': 'Pct Deg English',
    'PCIP24': 'Pct Deg Humanities',
    'PCIP25': 'Pct Deg Library',
    'PCIP26': 'Pct Deg Biological',
    'PCIP27': 'Pct Deg Mathematics',
    'PCIP29': 'Pct Deg Military',
    'PCIP30': 'Pct Deg Multidiscipline',
    'PCIP31': 'Pct Deg Parks Recreation Fitness',
    'PCIP38': 'Pct Deg Philosophy Religious',
    'PCIP39': 'Pct Deg Theology Religious Vocation',
    'PCIP40': 'Pct Deg Physical Science',
    'PCIP41': 'Pct Deg Science Technology',
    'PCIP42': 'Pct Deg Psychology',
    'PCIP43': 'Pct Deg Security Law Enforcement',
    'PCIP44': 'Pct Deg Public Administration Social Service',
    'PCIP45': 'Pct Deg Social Science',
    'PCIP46': 'Pct Deg Construction',
    'PCIP47': 'Pct Deg Mechanic Repair Technology',
    'PCIP48': 'Pct Deg Precision Production',
    'PCIP49': 'Pct Deg Transportation',
    'PCIP50': 'Pct Deg Visual Performing',
    'PCIP51': 'Pct Deg Health',
    'PCIP52': 'Pct Deg Business Marketing',
    'PCIP54': 'Pct Deg History'
}
df.rename(columns=pcip_to_pctdeg)
